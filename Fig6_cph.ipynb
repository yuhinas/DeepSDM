# %%
from Utils import PlotUtlis, Beta, create_folder, mm2inch, set_mpl_defaults, logistic

import matplotlib.pyplot as plt
import numpy as np
import os
import json
import scipy

set_mpl_defaults()

# %%
run_id = 'e52c8ac9a3e24c75ac871f63bbdea060'
exp_id = '115656750127464383'
niche_rst_size = 100

# %%
PU = PlotUtlis(run_id = run_id, exp_id = exp_id, niche_rst_size = niche_rst_size)

# %%
create_folder(PU.plot_path_cph)

# %% [markdown]
# # 畫地理中心與棲位中心所算得的Spearman's rho

# %%
df_spearman_ecogeo, niche_beta_params, geographical_beta_params = PU.calculate_cph_spearman_beta()
# Out:
# Processing species: Abroscopus_albogularis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Accipiter_virgatustus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Acridotheres_cristatellus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Actinodura_morrisoniana
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Aegithalos_concinnus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Alauda_gulgula
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Amaurornis_phoenicurus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Arborophila_crudigularis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Brachypteryx_goodfellowi
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Caprimulgus_affinis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Carpodacus_formosanus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Cecropis_striolata
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Centropus_bengalensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Chalcophaps_indica
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Cinclus_pallasii
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Cisticola_exilis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Cisticola_juncidis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Columba_pulchricollis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Coracina_macei
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Delichon_dasypuschos
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Dendrocopos_leucotos
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Dicaeum_ignipectus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Dicaeum_minullum
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Dicrurus_aeneus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Egretta_sacra
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Elanus_caeruleus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Enicurus_scouleri
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Ficedula_hyperythraa
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Fulvetta_formosana
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Gallinula_chloropus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Gallirallus_striatus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Garrulax_poecilorhynchus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Garrulax_ruficeps
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Garrulax_taewanus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Garrulus_glandarius
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Glaucidium_brodiei
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Gorsachius_melanolophus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Hirundapus_cochinchinensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Horornis_acanthizoides
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Horornis_fortipes
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Ictinaetus_malayensislus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Ixobrychus_cinnamomeus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Ketupa_flavipes
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Lanius_schach
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Liocichla_steerii
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Locustella_alishanensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Lonchura_atricapilla
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Lonchura_punctulata
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Lonchura_striata
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Lophura_swinhoii
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Oriolus_trailliiris
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Otus_lettia
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Otus_spilocephalus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Parus_holsti
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Passer_cinnamomeus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Periparus_aterolaris
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Pernis_ptilorhynchus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Phasianus_colchicus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Picus_canus_fuliginosus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Pnoepyga_formosana
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Poecile_varius
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Porzana_fuscamusicuscnemis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Prinia_flaviventris
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Prinia_inornata
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Prinia_striata
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Prunella_collaris
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Pycnonotus_taivanus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Pyrrhula_nipalensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Pyrrhula_owstoni
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Rallina_eurizonoides
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Regulus_goodfellowi
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Riparia_chinensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Rostratula_benghalensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Sinosuthora_webbiana
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Sitta_europaea
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Spizixos_semitorques
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Streptopelia_tranquebarica
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Strix_leptogrammica
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Suthora_verreauxi
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Synoicus_chinensis
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Syrmaticus_mikado
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Tarsiger_indicus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Tarsiger_johnstoniae
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Treron_formosae
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Treron_sieboldii
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Trochalopteron_morrisonianum
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Troglodytes_troglodytes
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Turdus_poliocephalus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Turnix_suscitator
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Turnix_sylvaticus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Tyto_longimembris
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Urocissa_caerulea
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Yungipicus_canicapillus
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Zoothera_dauma
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Zosterops_simplex

# %%
df_spearman_ecogeo.to_csv(PU.df_spearman_ecogeo_path, index = None)
with open(PU.niche_beta_params_path, 'w') as f:
    json.dump(niche_beta_params, f, indent = 4)
with open(PU.geographical_beta_params_path, 'w') as f:
    json.dump(geographical_beta_params, f, indent = 4)

# %%
bin_width = 0.05
bins = np.arange(-1, 0.4 + bin_width, bin_width)  # 建立範圍 -1 到 1，間隔為 0.1

fig, ax = plt.subplots(figsize = mm2inch(60, 40), gridspec_kw = {'left': 0.15, 'right': 0.95, 'bottom': 0.2, 'top': 0.95})
ax.hist(PU.df_spearman_ecogeo['rho'][PU.df_spearman_ecogeo.center_type == 'Geographical_center'], bins=bins, label='Geographic centroid', color='blue', alpha = 0.8)
ax.hist(PU.df_spearman_ecogeo['rho'][PU.df_spearman_ecogeo.center_type == 'Niche_center'], bins=bins, label='Niche centroid', color='orange', alpha = 0.8)

ax.legend(loc='upper right')  # 調整圖例字體大小
ax.set_xlabel(rf"Spearman's $\rho$")  # 調整x軸標籤字體大小
ax.set_ylabel('Number of species')  # 調整y軸標籤字體大小
ax.set_ylim(top = 100)

plot_output = os.path.join(PU.plot_path_cph, 'DeepSDM_rho_comparison_hist.pdf')
# plt.savefig(plot_output, dpi = 500, transparent = True)
plt.show()

# %%
# 1. 分別取出兩組 Spearman's ρ 值
rho_geo = PU.df_spearman_ecogeo.loc[PU.df_spearman_ecogeo.center_type == 'Geographical_center', 'rho'].dropna()
rho_eco = PU.df_spearman_ecogeo.loc[PU.df_spearman_ecogeo.center_type == 'Niche_center', 'rho'].dropna()

# ----------------------------
# 2. Kolmogorov–Smirnov (K-S) 雙樣本檢定
# ----------------------------
ks_stat, ks_pvalue = scipy.stats.ks_2samp(rho_geo, rho_eco)

print("=== Kolmogorov–Smirnov (K-S) test ===")
print(f"K-S statistic = {ks_stat:.4f}")
print(f"K-S p-value   = {ks_pvalue:.4e}")

# ----------------------------
# 3. Mann–Whitney U 檢定
# ----------------------------
# 如果你想檢驗的是雙尾(兩側)差異，請使用 alternative='two-sided'
# 如果你預期其中一組顯著較大或較小，可以改用 'greater' 或 'less'
mw_stat, mw_pvalue = scipy.stats.mannwhitneyu(rho_geo, rho_eco, alternative='two-sided')

print("=== Mann–Whitney U test ===")
print(f"U statistic   = {mw_stat:.4f}")
print(f"p-value       = {mw_pvalue:.4e}")

# ----------------------------
# 4. 補充：描述統計 (選擇性)
# ----------------------------
print("\n=== Descriptive statistics ===")
print("Geographical center (Spearman's rho):")
print(rho_geo.describe())
print("\nEcological center (Spearman's rho):")
print(rho_eco.describe())
# Out:
# === Kolmogorov–Smirnov (K-S) test ===
# K-S statistic = 1.0000
# K-S p-value   = 2.1928e-74
# === Mann–Whitney U test ===
# U statistic   = 15625.0000
# p-value       = 1.6456e-42
#
# === Descriptive statistics ===
# Geographical center (Spearman's rho):
# count    125.000000
# mean      -0.082397
# std        0.229950
# min       -0.410720
# 25%       -0.306920
# 50%       -0.057451
# 75%        0.133390
# max        0.291999
# Name: rho, dtype: float64
#
# Ecological center (Spearman's rho):
# count    125.000000
# mean      -0.826454
# std        0.027435
# min       -0.918464
# 25%       -0.841130
# 50%       -0.819734
# 75%       -0.810945
# max       -0.769728
# Name: rho, dtype: float64

# %% [markdown]
# # 以cluster內的所有點來算beta regression

# %%
niche_beta_cluster_params, geographical_beta_cluster_params = PU.calculate_cph_spearman_beta_cluster()
# Out:
# Processing species: Zoothera_daumaoglodytesianum
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Zosterops_simplexquebarica
# /home/klok0126/.local/lib/python3.10/site-packages/statsmodels/tools/numdiff.py:157: RuntimeWarning: invalid value encountered in scalar subtract
#   grad[k, :] = (f(*((x+ei,)+args), **kwargs) -
# Processing species: Yungipicus_canicapillusmis

# %%
with open(PU.niche_beta_cluster_params_path, 'w') as f:
    json.dump(niche_beta_cluster_params, f, indent = 4)
with open(PU.geographical_beta_cluster_params_path, 'w') as f:
    json.dump(geographical_beta_cluster_params, f, indent = 4)

# %%
fig, ax = plt.subplots(figsize=mm2inch(60, 40), 
                       gridspec_kw={'left': 0.15, 'right': 0.95, 
                                    'bottom': 0.2, 'top': 0.95})
# ---------------------------------------------------------
max_x_overall = 0.0
for i, species in enumerate(PU.species_list_predict):
    info = PU.geographical_beta_params[species]
    params_mu = np.array(info["params_mu"])
    x_min = info["x_min"]
    x_max = info["x_max"]
    y_min = info["y_min"]
    y_max = info["y_max"]
    eps   = info["epsilon"]

    if x_max > max_x_overall:
        max_x_overall = x_max
    
    x_line = np.linspace(x_min, x_max, 100)
    X_line = np.column_stack([np.ones_like(x_line), x_line])
    linear_pred = X_line @ params_mu
    mu_pred_norm = logistic(linear_pred)
    mu_pred = ((mu_pred_norm - eps) / (1 - 2*eps)) * (y_max - y_min) + y_min
    
    cluster_idx = PU.cluster_labels[i]  # 1,2,3
    c_idx = cluster_idx - 1
    ax.plot(x_line, mu_pred, color=PU.color_list[c_idx], alpha=0.1, linewidth=0.3)

# ---------------------------------------------------------
# 三個群集的平均線
# ---------------------------------------------------------
x_min_cluster = max([p['x_min'] for p in PU.geographical_beta_cluster_params.values()])
x_max_cluster = min([p['x_max'] for p in PU.geographical_beta_cluster_params.values()])

for cluster in range(1, 4):
    info = PU.geographical_beta_cluster_params[str(cluster)]    
    params_mu = np.array(info["params_mu"])
    phi = np.array(info["params_phi"])
    x_min = info["x_min"]
    x_max = info["x_max"]
    y_min = info["y_min"]
    y_max = info["y_max"]
    eps   = info["epsilon"]    
    
    x_line = np.linspace(x_min_cluster, x_max_cluster)
    X_line = np.column_stack([np.ones_like(x_line), x_line])
    linear_pred = X_line @ params_mu
    mu_pred_norm = logistic(linear_pred)
    mu_pred = ((mu_pred_norm - eps) / (1 - 2*eps)) * (y_max - y_min) + y_min
    
    color_idx = cluster - 1
    ax.plot(
        x_line, mu_pred,
        color=PU.color_list[color_idx],
        alpha=1.0,
        linewidth=1,
        label=f'Cluster {cluster}'
    )

ax.set_ylim(bottom=0, top=1)
ax.set_xlim(left=0, right=max_x_overall)
ax.set_ylabel('Environmental suitability')
ax.set_xlabel('Distance (km)')
ax.legend(loc='best')

plot_output = os.path.join(PU.plot_path_cph, 'geo_beta_reg.pdf')
# plt.savefig(plot_output, dpi=500, transparent=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=mm2inch(60, 40), 
                       gridspec_kw={'left': 0.15, 'right': 0.95, 
                                    'bottom': 0.2, 'top': 0.95})

max_x_overall = 0.0
for i, species in enumerate(PU.species_list_predict):
    info = PU.niche_beta_params[species]
    params_mu = np.array(info["params_mu"])
    x_min = info["x_min"]
    x_max = info["x_max"]
    y_min = info["y_min"]
    y_max = info["y_max"]
    eps   = info["epsilon"]

    if x_max > max_x_overall:
        max_x_overall = x_max
    
    x_line = np.linspace(x_min, x_max, 100)
    X_line = np.column_stack([np.ones_like(x_line), x_line])
    linear_pred = X_line @ params_mu
    mu_pred_norm = logistic(linear_pred)
    mu_pred = ((mu_pred_norm - eps) / (1 - 2*eps)) * (y_max - y_min) + y_min
    
    cluster_idx = PU.cluster_labels[i]  # 1,2,3
    c_idx = cluster_idx - 1
    ax.plot(x_line, mu_pred, color=PU.color_list[c_idx], alpha=0.1, linewidth=0.3)

x_min_cluster = max([p['x_min'] for p in PU.niche_beta_cluster_params.values()])
x_max_cluster = min([p['x_max'] for p in PU.niche_beta_cluster_params.values()])

for cluster in range(1, 4):
    info = PU.niche_beta_cluster_params[str(cluster)]    
    params_mu = np.array(info["params_mu"])
    phi = np.array(info["params_phi"])
    x_min = info["x_min"]
    x_max = info["x_max"]
    y_min = info["y_min"]
    y_max = info["y_max"]
    eps   = info["epsilon"]    
    
    x_line = np.linspace(x_min_cluster, x_max_cluster)
    X_line = np.column_stack([np.ones_like(x_line), x_line])
    linear_pred = X_line @ params_mu
    mu_pred_norm = logistic(linear_pred)
    mu_pred = ((mu_pred_norm - eps) / (1 - 2*eps)) * (y_max - y_min) + y_min

    color_idx = cluster - 1
    ax.plot(
        x_line, mu_pred,
        color=PU.color_list[color_idx],
        alpha=1.0,
        linewidth=1,
        label=f'Cluster {cluster}'
    )

ax.set_ylim(bottom=0, top=1)
ax.set_xlim(left=0, right=max_x_overall)
ax.set_ylabel('Environmental suitability')
ax.set_xlabel('Distance')
ax.legend(loc='best')

plot_output = os.path.join(PU.plot_path_cph, 'niche_beta_reg.pdf')
# plt.savefig(plot_output, dpi=500, transparent=True)
plt.show()

# %% [markdown]
# # 選幾個物種畫，一張一張存

# %%
species_to_print = ['Yuhina_brunneiceps', 'Psilopogon_nuchalis', 'Locustella_alishanensis', 'Gallinula_chloropus']

# %%
PU.plot_subplots(species_to_print)
